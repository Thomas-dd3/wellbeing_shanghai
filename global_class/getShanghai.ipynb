# %%
import pandas as pd
import geopandas as gpd
import shapely.ops

# %%
gdf_neighborhoods = pd.read_pickle('C:\\Users\\Roger\\Documents\\UTSEUS - GI04\\Hackathon\\pickles\\utseus-cendus-shanghai-neighborhoods.pk')
#shanghai = shapely.ops.unary_union(gdf_neighborhoods.geometry)
shanghai = gdf_neighborhoods.unary_union
shanghai = shanghai.simplify(0.01).buffer(0.01)
shanghai
